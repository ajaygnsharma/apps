# %%
from sympy import simplify
import sympy as sym
x = sym.symbols('x');

expr = 2*x + 3*x  - sym.sin(x) - 3*x + 42

# %%
s=simplify(expr);

# %%
s
# Out:
# 2*x - sin(x) + 42

# %%
expr = (2*x+5)*(x**2+3*x+4)

# %% [markdown]
# ### Lets expand two polynomials when they multiply each other

# %%
expr
# Out:
# (2*x + 5)*(x**2 + 3*x + 4)

# %%
expr.expand()
# Out:
# 2*x**3 + 11*x**2 + 23*x + 20

# %% [raw]
# ## Now lets Factor a polynomial

# %%
from sympy import factor
factor(x**2 - 2*x - 8)
# Out:
# (x - 4)*(x + 2)

# %% [markdown]
# ## Lets simplify some expressions and put them together

# %%
a,b,c = sym.symbols('a b c');
expr = (a*b/c + c*b/a)

# %%
expr
# Out:
# a*b/c + b*c/a

# %%
from sympy import together
together(expr)
# Out:
# b*(a**2 + c**2)/(a*c)

# %%
expr = (a*b/c - 1)

# %%
simplify(expr)
# Out:
# (a*b - c)/c

# %%
expr56_2 = (a*b/c + a*c/b)+(b*c/a)
simplify(expr56_2)
# Out:
# a*b/c + a*c/b + b*c/a

# %% [markdown]
# ### Its also easy to divide two polynomials

# %%
exp56_3a = (x**2 + 5*x -6)/(x - 1)
simplify(exp56_3a)
# Out:
# x + 6

# %%
sym.factor(x**2 + 5*x - 6)
# Out:
# (x - 1)*(x + 6)

# %%
simplify((a**3 + 8*b**3)/(a+2*b))
# Out:
# (a**3 + 8*b**3)/(a + 2*b)

# %% [markdown]
# ### We can factor polynomials quite easily

# %%
expr = a**3 + 8*b**3
factor(expr)
# Out:
# (a + 2*b)*(a**2 - 2*a*b + 4*b**2)

# %%
expr
# Out:
# a**3 + 8*b**3

# %%
simplify(factor(a**3 + 8*b**3)/(a+2*b))
# Out:
# a**2 - 2*a*b + 4*b**2

# %%
factor(8*x**2+18*x-5)
# Out:
# (2*x + 5)*(4*x - 1)
