# %%
from sympy import sympify, S, evalf, N

# %%
S(1/7)
# Out:
# 0.142857142857143

# %%
S('1/7')
# Out:
# 1/7

# %%
from sympy import *

# %%
x,y,z = symbols('x y z');

# %%
x+2
# Out:
# x + 2

# %%
y = x+2

# %%
y
# Out:
# x + 2

# %%
a0,a1,a2,a3= symbols('a0:4')

# %%
E
# Out:
# E

# %%
E.evalf()
# Out:
# 2.71828182845905

# %% [markdown]
# This evaluates the value of E. E is essentially an object and evalf is its method
